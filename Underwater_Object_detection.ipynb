# %% [markdown]
# <a href="https://colab.research.google.com/github/subasri-harsitha/Underwater-Object-detection/blob/main/Underwater_Object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 899.0/899.0 kB 27.2 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 49.7M/49.7M [00:00<00:00, 358MB/s]

# %%
from ultralytics import YOLO

model = YOLO('yolov8m.pt')

model.train(data='/content/drive/MyDrive/yolo/data.yaml', epochs=100, save=True, save_dir='/content/drive/MyDrive/yolo/train_results')

# %%
import shutil

source_dir = '/content/runs/detect/train'
destination_dir = '/content/drive/MyDrive/yolo/results'

try:
    shutil.copytree(source_dir, destination_dir)
    print(f"Directory copied to {destination_dir}")
except FileNotFoundError:
    print("Source directory not found. Please check the path.")
except FileExistsError:
    print("Destination directory already exists. Try a different name.")
# Out:
# Destination directory already exists. Try a different name.

# %%
from ultralytics import YOLO
import cv2
import matplotlib.pyplot as plt
import os

model = YOLO('/content/drive/MyDrive/yolo/results/weights/best.pt')
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.

# %%
results = model.predict(
    source='/content/drive/MyDrive/yolo/image.jpeg',
    save=True,
    save_dir='/content/drive/MyDrive/yolo/result'
)
# Out:
# image 1/1 /content/drive/MyDrive/yolo/download.jpeg: 448x640 5 pbottles, 101.2ms
# Speed: 8.3ms preprocess, 101.2ms inference, 943.4ms postprocess per image at shape (1, 3, 448, 640)
# Results saved to runs/detect/predict

# %%
import shutil

source_dir = '/content/runs/detect/predict/image.jpg'
destination_dir = '/content/drive/MyDrive/yolo/result/predict'


shutil.copy(source_dir, destination_dir)
# Out:
# '/content/drive/MyDrive/yolo/result/predict/download.jpg'

# %%
import cv2
from google.colab.patches import cv2_imshow

image = cv2.imread('/content/drive/MyDrive/yolo/result/predict/image.jpg')
if image is not None:
    image_rgb = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)
    cv2_imshow(image_rgb)
else:
    print("Error: Unable to load image. The file might be corrupted.")
# Out:
# <PIL.Image.Image image mode=RGB size=275x183>
